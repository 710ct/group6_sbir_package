# %% [markdown]
# ### For our Project (Just paste all of the rest things in Terminal)

# %%
import meeko
print("meeko works")
# Out:
# meeko works

# %%
from rdkit import Chem
import meeko
print("WORKS")
# Out:
# WORKS

# %% [markdown]
# First, we will use PDBFixer to clean the structure and add missing hydrogens at a physiological pH (7.4):

# %% [raw]
# !pdbfixer 4AUO.pdb \
# --output MMP1_receptorH.pdb \
# --keep-heterogens=all \
# --replace-nonstandard \
# --ph=7.4

# %% [raw]
# !python -m meeko.cli.mk_prepare_receptor \
# -i MMP1_receptorH.pdb -o flex_receptor -p -v \
# --box_center 64.610 17.949 12.734 \
# --box_size 25 25 25 \
# -f A:219 -a

# %%
import os

for i in range(1, 21):
    file = f'./ligands_raw/ligand_raw_{i}.sdf'
    print(file, os.path.exists(file), os.path.getsize(file) if os.path.exists(file) else "missing")
# Out:
# ./ligands_raw/ligand_raw_1.sdf True 8339
# ./ligands_raw/ligand_raw_2.sdf True 7513
# ./ligands_raw/ligand_raw_3.sdf True 8540
# ./ligands_raw/ligand_raw_4.sdf True 7709
# ./ligands_raw/ligand_raw_5.sdf True 7709
# ./ligands_raw/ligand_raw_6.sdf True 8399
# ./ligands_raw/ligand_raw_7.sdf True 7840
# ./ligands_raw/ligand_raw_8.sdf True 9628
# ./ligands_raw/ligand_raw_9.sdf True 9355
# ./ligands_raw/ligand_raw_10.sdf True 7431
# ./ligands_raw/ligand_raw_11.sdf True 1124
# ./ligands_raw/ligand_raw_12.sdf True 6765
# ./ligands_raw/ligand_raw_13.sdf True 7818
# ./ligands_raw/ligand_raw_14.sdf True 8421
# ./ligands_raw/ligand_raw_15.sdf True 6125
# ./ligands_raw/ligand_raw_16.sdf True 6923
# ./ligands_raw/ligand_raw_17.sdf True 8399
# ./ligands_raw/ligand_raw_18.sdf True 8329
# ./ligands_raw/ligand_raw_19.sdf True 7845
# ./ligands_raw/ligand_raw_20.sdf True 5893

# %%
for i in range(1, 21):
    cmd = f"python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_{i}.sdf -o ./ligands/ligand_{i}.pdbqt"
    print(cmd)
    # !{cmd}
# Out:
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_1.sdf -o ./ligands/ligand_1.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_2.sdf -o ./ligands/ligand_2.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_3.sdf -o ./ligands/ligand_3.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_4.sdf -o ./ligands/ligand_4.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_5.sdf -o ./ligands/ligand_5.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_6.sdf -o ./ligands/ligand_6.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_7.sdf -o ./ligands/ligand_7.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_8.sdf -o ./ligands/ligand_8.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_9.sdf -o ./ligands/ligand_9.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_10.sdf -o ./ligands/ligand_10.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_11.sdf -o ./ligands/ligand_11.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_12.sdf -o ./ligands/ligand_12.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_13.sdf -o ./ligands/ligand_13.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_14.sdf -o ./ligands/ligand_14.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_15.sdf -o ./ligands/ligand_15.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_16.sdf -o ./ligands/ligand_16.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_17.sdf -o ./ligands/ligand_17.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_18.sdf -o ./ligands/ligand_18.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_19.sdf -o ./ligands/ligand_19.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')
# python -m meeko.cli.mk_prepare_ligand -i ./ligands_raw/ligand_raw_20.sdf -o ./ligands/ligand_20.pdbqt
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_prepare_ligand' (ModuleNotFoundError: No module named 'meeko.cli')

# %%
for i in range(1, 21):
    cmd = f"""
    ./vina --config config.txt \
    --receptor flex_receptor_rigid.pdbqt \
    --flex flex_receptor_flex.pdbqt \
    --ligand ./ligands/ligand_{i}.pdbqt \
    --exhaustiveness 6 \
    --out ./results/output_ligand_{i}.pdbqt
    """
    print(cmd)
    # !{cmd}
# Out:
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_1.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_1.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_2.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_2.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_3.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_3.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_4.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_4.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_5.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_5.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_6.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_6.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_7.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_7.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_8.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_8.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_9.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_9.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_10.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_10.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_11.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_11.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_12.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_12.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_13.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_13.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_14.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_14.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_15.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_15.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_16.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_16.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_17.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_17.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_18.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_18.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_19.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_19.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory
#
#     ./vina --config config.txt     --receptor flex_receptor_rigid.pdbqt     --flex flex_receptor_flex.pdbqt     --ligand ./ligands/ligand_20.pdbqt     --exhaustiveness 6     --out ./results/output_ligand_20.pdbqt
#
# /bin/bash: line 2: ./vina: No such file or directory

# %%
for i in range(1, 21):
    cmd = f"""
    python -m meeko.cli.mk_export \
    ./results/output_ligand_{i}.pdbqt \
    -s ./results/output_visual_ligand_{i}.sdf -k
    """
    print(cmd)
    # !{cmd}
# Out:
#     python -m meeko.cli.mk_export     ./results/output_ligand_1.pdbqt     -s ./results/output_visual_ligand_1.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_2.pdbqt     -s ./results/output_visual_ligand_2.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_3.pdbqt     -s ./results/output_visual_ligand_3.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_4.pdbqt     -s ./results/output_visual_ligand_4.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_5.pdbqt     -s ./results/output_visual_ligand_5.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_6.pdbqt     -s ./results/output_visual_ligand_6.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_7.pdbqt     -s ./results/output_visual_ligand_7.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_8.pdbqt     -s ./results/output_visual_ligand_8.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_9.pdbqt     -s ./results/output_visual_ligand_9.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_10.pdbqt     -s ./results/output_visual_ligand_10.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_11.pdbqt     -s ./results/output_visual_ligand_11.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_12.pdbqt     -s ./results/output_visual_ligand_12.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_13.pdbqt     -s ./results/output_visual_ligand_13.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_14.pdbqt     -s ./results/output_visual_ligand_14.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_15.pdbqt     -s ./results/output_visual_ligand_15.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_16.pdbqt     -s ./results/output_visual_ligand_16.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_17.pdbqt     -s ./results/output_visual_ligand_17.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_18.pdbqt     -s ./results/output_visual_ligand_18.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_19.pdbqt     -s ./results/output_visual_ligand_19.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')
#
#     python -m meeko.cli.mk_export     ./results/output_ligand_20.pdbqt     -s ./results/output_visual_ligand_20.sdf -k
#
# /srv/conda/envs/notebook/bin/python: Error while finding module specification for 'meeko.cli.mk_export' (ModuleNotFoundError: No module named 'meeko.cli')

# %% [raw]
# vina --config config.txt \
# --receptor flex_receptor_rigid.pdbqt \
# --flex flex_receptor_flex.pdbqt \
# --ligand ./ligands/ligand_${i}.pdbqt \
# --exhaustiveness 18 \
# --out ./results/output_ligand_${i}.pdbqt | tee ./results/log_ligand_${i}.txt
#
# mk_export.py ./results/output_ligand_${i}.pdbqt -s ./results/output_visual_ligand_${i}.sdf -k
# done

# %% [markdown]
# ### TO DO
# 1. In 'config.txt', find center(x,y,z), select 'box size'
# 2. Prepare Receptor
#    - Download the receptor (MMP-1), change the name in the second cell
#    - Use PDBFixer to clean the structure. For us, we have to add Ca2+, Zn2+
#    - In the Third cell, change 'A:203' to the correct part according to where Zn2+ is in!
#    - Download 20 ligands we will use in the 'ligands_raw' folder as ligand_raw_{#}.sdf
#      - REMEMBER: Make a separate chart for yourself to know the name of the ligands (e.g. ligand_1: Batimastat)

# %% [markdown]
# ### IN NOTEBOOK

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

def extract_result(input_file, csv_file):
    with open(input_file, 'r') as f:
        lines = f.readlines()

    data_rows = []
    start_collecting = False

    for line in lines:
        if '-----+' in line:
            start_collecting = True
            continue

        if start_collecting and line.strip():
            parts = line.split()
            if parts and parts[0].isdigit():
                data_rows.append(parts[1:])

    with open(csv_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['affinity', 'rmsd_lb', 'rmsd_ub'])
        writer.writerows(data_rows)

n = 20

for i in range(1, n+1):
    extract_result(f'./results/log_ligand_{i}.txt',
                   f'./table_results/table_ligand_{i}.csv')
# Out:
# /srv/conda/envs/notebook/lib/python3.11/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# /srv/conda/envs/notebook/lib/python3.11/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /srv/conda/envs/notebook/lib/python3.11/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /srv/conda/envs/notebook/lib/python3.11/site-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
#   ParserElement.enablePackrat()
# In /srv/conda/envs/notebook/lib/python3.11/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string'
# In /srv/conda/envs/notebook/lib/python3.11/site-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'resetCache' deprecated - use 'reset_cache'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 30
#      27 n = 20
#      29 for i in range(1, n+1):
# ---> 30     extract_result(f'./results/log_ligand_{i}.txt',
#      31                    f'./table_results/table_ligand_{i}.csv')
#
# Cell In[7], line 22, in extract_result(input_file, csv_file)
#      19         if parts and parts[0].isdigit():
#      20             data_rows.append(parts[1:])
# ---> 22 with open(csv_file, 'w', newline='') as f:
#      23     writer = csv.writer(f)
#      24     writer.writerow(['affinity', 'rmsd_lb', 'rmsd_ub'])
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './table_results/table_ligand_1.csv'

# %%
best_affinity = {}

for i in range(1, n+1):
    df = pd.read_csv(f'./table_results/table_ligand_{i}.csv')
    best_affinity[f'ligand_{i}'] = df['affinity'].iloc[0]

print(best_affinity)

# %%
sort_affinity = dict(sorted(best_affinity.items(), key=lambda item: item[1]))

plt.figure(figsize=(10,6))
plt.bar(sort_affinity.keys(), sort_affinity.values())
plt.title("Binding Affinity (kcal/mol)")
plt.xlabel("Ligand")
plt.ylabel("Affinity")
plt.show()

# %%
for i in range(1, n+1):
    extract_result(f'./results/log_ligand_{i}.txt', f'./table_results/table_ligand_{i}.csv')
    #table_list.append(f'table_ligand_{i}.csv')

# %%
#Extract the affinity of mode 1 into a dictionary
best_affinity = {}

for i in range(1, n+1):
    df = pd.read_csv(f'./table_results/table_ligand_{i}.csv')
    best_affinity.update({f'ligand_{i}' : df['affinity'].iloc[0]})
    
print(best_affinity)

#Sort 20 ligands from lowest to highest affinity
sort_affinity = dict(sorted(best_affinity.items(), key=lambda item: item[1]))

print(sort_affinity)

# %%
#Show the affinity of all 20 ligands
plt.figure(figsize=(10, 6))

plt.bar(sort_affinity.keys(), sort_affinity.values(), color='skyblue', edgecolor='black')

plt.title('Best affinity of ligands (kcal/mol)', fontsize=14)
plt.xlabel('Ligand', fontsize=12)
plt.ylabel('Affinity', fontsize=12)

plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.show()

# %%
#Plot rmsd_ub of all 20 ligands
plt.figure(figsize=(10, 6))

cmap = plt.cm.tab20
for i in range(1, n+1):
    df = pd.read_csv(f'./table_results/table_ligand_{i}.csv')
    plt.plot(df['rmsd_ub'] , marker='o', linestyle='-', color=cmap(i), label=f'ligand_{i}')

plt.title(f'Line Chart of rmsd_ub', fontsize=14)
plt.xlabel('Number of Mode', fontsize=12)
plt.ylabel('rmsd_ub', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

plt.xticks(range(9), range(1, 10))
plt.show()

# %% [markdown]
# ### From lab 5

# %%
mk_prepare_receptor.py -i MMP1_receptorH.pdb -o flex_receptor -p -v \ 
#mk_prepare_receptor.py -i beta2ar_receptorH.pdb (name of the receptor we are using) -o flex_receptor -p -v \ 
--box_center 64.610 17.949 12.734 \ #Find the point of Zn2+
--box_size 25.0 25.0 25.0 \ #Set the size based on the paper
-f A:203 -a #Find 1~3 places

# %%
vina --config config.txt \
--receptor flex_receptor_rigid.pdbqt \
--flex flex_receptor_flex.pdbqt \
--exhaustiveness 6 \
--out output_flex.pdbqt | tee log_flex.txt

# %%
mk_export.py output_flex.pdbqt -s output_flex_poses_withflex.sdf -k

# %%
vina --config config.txt --out output.pdbqt | tee log.txt

# %%
import sys
print(sys.executable)

# %% [markdown]
# ### Trying to do with Python..

# %%
import os

ligand_dir = './ligands'
result_dir = './results'
config_file = 'config.txt'

if not os.path.exists(result_dir):
    os.makedirs(result_dir)

# %%
# !mk_prepare_receptor.py -i MMP1_receptorH.pdb -o flex_receptor -p -v --box_center 64.610 17.949 12.734 --box_size 25.0 25.0 25.0 -f A:203 -a

# %% [markdown]
# Checkpoint: you have both flex_receptor_rigid.pdbqt and flex_receptor_flex.pdbqt, plus
# flex_receptor.box.txt.

# %% [markdown]
# mk_prepare_receptor.py -i MMP1_receptorH.pdb -o flex_receptor -p -v \
# #mk_prepare_receptor.py -i MMP1_receptorH.pdb (name of the receptor we are using) -o flex_receptor -p -v \
# --box_center 64.610 17.949 12.734 \ #Find the point of Zn2+
# --box_size 25.0 25.0 25.0 \ #Set the size based on the paper
# -f A:203 -a #Find 1~3 places

# %%
for i in range(1, 21):
    # !vina --config config.txt \
          --receptor flex_receptor_rigid.pdbqt \
          --flex flex_receptor_flex.pdbqt \
          --ligand ./ligands/ligand_{i}.pdbqt \
          --exhaustiveness 6 \
          --out ./results/output_ligand_{i}.pdbqt | tee ./results/log_ligand_{i}.txt

    # !mk_export.py ./results/output_ligand_{i}.pdbqt -s ./results/output_visual_ligand_{i}.sdf -k

# %%
for i in range(1, 21):
    ligand_name = f"ligand_{i}.pdbqt"
    input_path = os.path.join(ligand_dir, ligand_name)

    output_pdbqt = os.path.join(result_dir, f"output_ligand_{i}.pdbqt")
    log_file = os.path.join(result_dir, f"log_ligand_{i}.txt")
    output_sdf = os.path.join(result_dir, f"output_visual_ligand_{i}.sdf")

    # !vina --config {config_file} \
          --receptor flex_receptor_rigid.pdbqt \
          --flex flex_receptor_flex.pdbqt \
          --ligand {input_path} \
          --exhaustiveness 6 \
          --out {output_pdbqt} | tee {log_file}

    # !mk_export.py {output_pdbqt} -s {output_sdf} -k

# %%
for i in range(1, 21):
    ligand_name = f"ligand_{i}.pdbqt"
    input_path = os.path.join(ligand_dir, ligand_name)

    output_pdbqt = os.path.join(result_dir, f"output_ligand_{i}.pdbqt")
    log_file = os.path.join(result_dir, f"log_ligand_{i}.txt")
    output_sdf = os.path.join(result_dir, f"output_visual_ligand_{i}.sdf")

    # !vina --config {config_file} \
          --receptor flex_receptor_rigid.pdbqt \
          --flex flex_receptor_flex.pdbqt \
          --ligand {input_path} \
          --exhaustiveness 6 \
          --out {output_pdbqt} | tee {log_file}

    # !mk_export.py {output_pdbqt} -s {output_sdf} -k

# %% [markdown]
# Checkpoint: output_ligand{i}.pdbqt and log_ligand{i}.txt, output_visual_ligand{i} were created.
